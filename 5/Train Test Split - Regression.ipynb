# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from sklearn import linear_model

# %%
n = 100
x = np.linspace(0.01, 1, n).reshape(-1, 1)
y = np.linspace(0.01, 1, n)  + np.random.rand(n) - .5


plt.scatter(x,y)

# %%
y
# Out:
# array([-4.20014332e-01,  6.63047553e-02,  5.09156976e-03,  5.18051582e-01,
#        -4.05316668e-01, -1.88316702e-01,  5.26354918e-01,  4.77616803e-01,
#        -2.78892992e-01,  4.46847148e-01,  7.26634147e-03, -3.18988020e-01,
#         2.87124174e-02,  5.81302200e-02,  5.15355465e-01, -2.27496718e-01,
#         3.65101317e-01,  1.65780006e-01,  1.80858359e-01, -1.67176924e-01,
#        -1.77400617e-02,  7.09914262e-01,  3.80475529e-01,  4.67549118e-01,
#         3.34610398e-01, -1.41271360e-02,  2.05214176e-03,  3.28413834e-01,
#         7.17105095e-01,  3.29152792e-01,  3.95913601e-04,  3.83243620e-01,
#         2.70241032e-02,  8.76663036e-03,  3.79200889e-01,  7.58432145e-01,
#         4.50111900e-01,  6.99078599e-01, -2.50148038e-02, -3.69232671e-02,
#         7.82090834e-01, -6.65339599e-02,  4.01801063e-01,  2.40245245e-02,
#         3.25289054e-01,  7.00845258e-01, -1.98950940e-02,  6.12351433e-01,
#         3.05509068e-01,  3.59629424e-01,  9.23592149e-01,  5.56716802e-01,
#         9.50364122e-01,  1.77130365e-01,  4.38308593e-01,  6.77079276e-01,
#         3.29440726e-01,  6.67708837e-01,  5.12094692e-01,  4.20935915e-01,
#         7.12761978e-01,  3.97100348e-01,  3.41485308e-01,  6.76984870e-01,
#         1.88601150e-01,  5.47563305e-01,  5.61096882e-01,  9.68526703e-01,
#         6.16451216e-01,  3.86511035e-01,  5.57204305e-01,  3.12850718e-01,
#         6.37337298e-01,  6.56489953e-01,  8.58209468e-01,  2.65302645e-01,
#         6.48180361e-01,  3.57126841e-01,  9.98974004e-01,  7.96322643e-01,
#         1.21156550e+00,  8.34454269e-01,  1.18837817e+00,  1.26194452e+00,
#         7.16320648e-01,  9.41466726e-01,  4.38353071e-01,  1.22163844e+00,
#         1.17914815e+00,  9.54846193e-01,  1.20131974e+00,  1.12782909e+00,
#         1.27118881e+00,  1.06984943e+00,  1.33322406e+00,  1.43792229e+00,
#         8.46008512e-01,  1.03425395e+00,  1.08530959e+00,  9.54739756e-01])

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_, model.intercept_
# Out:
# (array([1.11928492]), -0.07413572942840124)

# %%
plt.scatter(x,y)
plt.plot(x, np.dot(x, model.coef_) + model.intercept_)

# %% [markdown]
# ## How do we "test" this model on "new" data if we don't have a new dataset?

# %% [markdown]
# ### Instead of using all of our data to produce this model, let's use some, and save the rest as a reserve

# %%
model = LinearRegression()
model.fit(x[:50], y[:50])
model.coef_, model.intercept_
# Out:
# (array([0.77670356]), 0.01518262966748285)

# %%
plt.scatter(x[:50],y[:50])
plt.plot(x[:50], np.dot(x[:50], model.coef_) + model.intercept_)

# %%
plt.scatter(x,y)
plt.plot(x, np.dot(x, model.coef_) + model.intercept_)

# %% [markdown]
# ## Our slope doesn't match the previous slope with all the data. Why not?
# ## Let's plot all of our data with this model to see

# %%
plt.scatter(x,y)
plt.plot(x, np.dot(x, model.coef_) + model.intercept_)

# %% [markdown]
# ## We only used the first half of our data and neglected the second half.

# %% [markdown]
# ### Let's try this again differently. Let's shuffle our data first

# %%
def shuffle(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return p

# %%
p = shuffle(x, y)

# %%
p
# Out:
# array([78, 45, 12, 76, 30, 29, 59, 42, 39, 28, 32, 94, 43, 73, 87,  1, 74,
#        44,  3, 57, 60, 77, 40, 33, 11,  6, 21,  7, 36, 17, 46, 89, 31, 90,
#        71, 72, 19, 63, 93, 92, 62, 75, 10, 58, 22,  0, 53, 37, 91, 99, 54,
#        80, 18, 15, 50, 85, 69, 98, 13,  8, 56, 95, 96, 84, 47, 81, 86, 41,
#        48, 64, 51, 68, 49, 67, 52, 38, 23, 14, 16, 65,  5, 26, 82, 24, 34,
#         9,  4, 20, 61, 27,  2, 83, 88, 79, 66, 35, 70, 97, 55, 25])

# %%
x[[2, 0, 1, 4]]
# Out:
# array([[0.03],
#        [0.01],
#        [0.02],
#        [0.05]])

# %%
x[[61, 27, 92]], y[[61, 27, 92]]
# Out:
# (array([[0.62],
#         [0.28],
#         [0.93]]), array([0.39710035, 0.32841383, 1.27118881]))

# %%
x[p], y[p]
# Out:
# (array([[0.79],
#         [0.46],
#         [0.13],
#         [0.77],
#         [0.31],
#         [0.3 ],
#         [0.6 ],
#         [0.43],
#         [0.4 ],
#         [0.29],
#         [0.33],
#         [0.95],
#         [0.44],
#         [0.74],
#         [0.88],
#         [0.02],
#         [0.75],
#         [0.45],
#         [0.04],
#         [0.58],
#         [0.61],
#         [0.78],
#         [0.41],
#         [0.34],
#         [0.12],
#         [0.07],
#         [0.22],
#         [0.08],
#         [0.37],
#         [0.18],
#         [0.47],
#         [0.9 ],
#         [0.32],
#         [0.91],
#         [0.72],
#         [0.73],
#         [0.2 ],
#         [0.64],
#         [0.94],
#         [0.93],
#         [0.63],
#         [0.76],
#         [0.11],
#         [0.59],
#         [0.23],
#         [0.01],
#         [0.54],
#         [0.38],
#         [0.92],
#         [1.  ],
#         [0.55],
#         [0.81],
#         [0.19],
#         [0.16],
#         [0.51],
#         [0.86],
#         [0.7 ],
#         [0.99],
#         [0.14],
#         [0.09],
#         [0.57],
#         [0.96],
#         [0.97],
#         [0.85],
#         [0.48],
#         [0.82],
#         [0.87],
#         [0.42],
#         [0.49],
#         [0.65],
#         [0.52],
#         [0.69],
#         [0.5 ],
#         [0.68],
#         [0.53],
#         [0.39],
#         [0.24],
#         [0.15],
#         [0.17],
#         [0.66],
#         [0.06],
#         [0.27],
#         [0.83],
#         [0.25],
#         [0.35],
#         [0.1 ],
#         [0.05],
#         [0.21],
#         [0.62],
#         [0.28],
#         [0.03],
#         [0.84],
#         [0.89],
#         [0.8 ],
#         [0.67],
#         [0.36],
#         [0.71],
#         [0.98],
#         [0.56],
#         [0.26]]),
#  array([ 9.98974004e-01,  7.00845258e-01,  2.87124174e-02,  6.48180361e-01,
#          3.95913601e-04,  3.29152792e-01,  4.20935915e-01,  4.01801063e-01,
#         -3.69232671e-02,  7.17105095e-01,  2.70241032e-02,  1.33322406e+00,
#          2.40245245e-02,  6.56489953e-01,  1.22163844e+00,  6.63047553e-02,
#          8.58209468e-01,  3.25289054e-01,  5.18051582e-01,  6.67708837e-01,
#          7.12761978e-01,  3.57126841e-01,  7.82090834e-01,  8.76663036e-03,
#         -3.18988020e-01,  5.26354918e-01,  7.09914262e-01,  4.77616803e-01,
#          4.50111900e-01,  1.65780006e-01, -1.98950940e-02,  9.54846193e-01,
#          3.83243620e-01,  1.20131974e+00,  3.12850718e-01,  6.37337298e-01,
#         -1.67176924e-01,  6.76984870e-01,  1.06984943e+00,  1.27118881e+00,
#          3.41485308e-01,  2.65302645e-01,  7.26634147e-03,  5.12094692e-01,
#          3.80475529e-01, -4.20014332e-01,  1.77130365e-01,  6.99078599e-01,
#          1.12782909e+00,  9.54739756e-01,  4.38308593e-01,  1.21156550e+00,
#          1.80858359e-01, -2.27496718e-01,  9.23592149e-01,  9.41466726e-01,
#          3.86511035e-01,  1.08530959e+00,  5.81302200e-02, -2.78892992e-01,
#          3.29440726e-01,  1.43792229e+00,  8.46008512e-01,  7.16320648e-01,
#          6.12351433e-01,  8.34454269e-01,  4.38353071e-01, -6.65339599e-02,
#          3.05509068e-01,  1.88601150e-01,  5.56716802e-01,  6.16451216e-01,
#          3.59629424e-01,  9.68526703e-01,  9.50364122e-01, -2.50148038e-02,
#          4.67549118e-01,  5.15355465e-01,  3.65101317e-01,  5.47563305e-01,
#         -1.88316702e-01,  2.05214176e-03,  1.18837817e+00,  3.34610398e-01,
#          3.79200889e-01,  4.46847148e-01, -4.05316668e-01, -1.77400617e-02,
#          3.97100348e-01,  3.28413834e-01,  5.09156976e-03,  1.26194452e+00,
#          1.17914815e+00,  7.96322643e-01,  5.61096882e-01,  7.58432145e-01,
#          5.57204305e-01,  1.03425395e+00,  6.77079276e-01, -1.41271360e-02]))

# %%
plt.scatter(x[p],y[p])

# %% [markdown]
# ### Still plots the same scatter plot

# %% [markdown]
# ### So, let's use the first 50 points of the shuffled data instead and see if the model is similar

# %%
model = LinearRegression()
model.fit(x[p][:50], y[p][:50])
model.coef_, model.intercept_
# Out:
# (array([ 0.98196171]), -0.010870046002644351)

# %% [markdown]
# ### Success! We got a similar slope as before with half of the points

# %%
plt.scatter(x,y)
plt.plot(x, np.dot(x, model.coef_) + model.intercept_)

# %% [markdown]
# ###  So how do we check the validity of the model on the rest of the points? The loss (Error) function of course!
# ### $E = \Sigma err(y - \hat{y}) = \Sigma err(y - \beta \cdot x)$
#
# ### $E = \frac{1}{N}\Sigma err( y - \hat{y}) = \frac{1}{N}\Sigma err(y - \beta \cdot x)$
# ### Why divide by N?
# This way we have a _mean_ error that's invariant to the number of points you use to build your model. Otherwise, your error would increase with the number of points

# %%
x[50:]
# Out:
# array([[ 0.51],
#        [ 0.52],
#        [ 0.53],
#        [ 0.54],
#        [ 0.55],
#        [ 0.56],
#        [ 0.57],
#        [ 0.58],
#        [ 0.59],
#        [ 0.6 ],
#        [ 0.61],
#        [ 0.62],
#        [ 0.63],
#        [ 0.64],
#        [ 0.65],
#        [ 0.66],
#        [ 0.67],
#        [ 0.68],
#        [ 0.69],
#        [ 0.7 ],
#        [ 0.71],
#        [ 0.72],
#        [ 0.73],
#        [ 0.74],
#        [ 0.75],
#        [ 0.76],
#        [ 0.77],
#        [ 0.78],
#        [ 0.79],
#        [ 0.8 ],
#        [ 0.81],
#        [ 0.82],
#        [ 0.83],
#        [ 0.84],
#        [ 0.85],
#        [ 0.86],
#        [ 0.87],
#        [ 0.88],
#        [ 0.89],
#        [ 0.9 ],
#        [ 0.91],
#        [ 0.92],
#        [ 0.93],
#        [ 0.94],
#        [ 0.95],
#        [ 0.96],
#        [ 0.97],
#        [ 0.98],
#        [ 0.99],
#        [ 1.  ]])

# %%
np.dot(x[50:], model.coef_) + model.intercept_
# Out:
# array([ 0.48993043,  0.49975004,  0.50956966,  0.51938928,  0.52920889,
#         0.53902851,  0.54884813,  0.55866775,  0.56848736,  0.57830698,
#         0.5881266 ,  0.59794621,  0.60776583,  0.61758545,  0.62740507,
#         0.63722468,  0.6470443 ,  0.65686392,  0.66668353,  0.67650315,
#         0.68632277,  0.69614239,  0.705962  ,  0.71578162,  0.72560124,
#         0.73542085,  0.74524047,  0.75506009,  0.76487971,  0.77469932,
#         0.78451894,  0.79433856,  0.80415817,  0.81397779,  0.82379741,
#         0.83361702,  0.84343664,  0.85325626,  0.86307588,  0.87289549,
#         0.88271511,  0.89253473,  0.90235434,  0.91217396,  0.92199358,
#         0.9318132 ,  0.94163281,  0.95145243,  0.96127205,  0.97109166])

# %%
y[50:] - (np.dot(x[50:], model.coef_) + model.intercept_)
# Out:
# array([ 0.19261653, -0.16031614, -0.33791644, -0.12148431, -0.22998924,
#         0.29130786,  0.31980442,  0.2211275 , -0.46216532,  0.2625585 ,
#        -0.25658725, -0.19369263, -0.23046511,  0.18147208,  0.01718603,
#         0.01999751, -0.00559431, -0.17497673,  0.25666823, -0.05532248,
#         0.32786613,  0.06768897,  0.3832    ,  0.15462971,  0.23775027,
#        -0.13476111,  0.09907278, -0.19456516,  0.13648098,  0.46122714,
#        -0.14350629, -0.37943318,  0.23366662, -0.12307479,  0.2614342 ,
#         0.36143925,  0.21240424, -0.13798553, -0.37602985, -0.38939267,
#        -0.02727681, -0.13132977,  0.06242422, -0.31910053,  0.02647942,
#         0.30715083, -0.13502809, -0.21748276, -0.30891248, -0.43667655])

# %%
np.square(y[50:] - (np.dot(x[50:], model.coef_) + model.intercept_))
# Out:
# array([  3.71011267e-02,   2.57012645e-02,   1.14187518e-01,
#          1.47584375e-02,   5.28950492e-02,   8.48602697e-02,
#          1.02274868e-01,   4.88973730e-02,   2.13596779e-01,
#          6.89369685e-02,   6.58370170e-02,   3.75168358e-02,
#          5.31141684e-02,   3.29321147e-02,   2.95359470e-04,
#          3.99900257e-04,   3.12963503e-05,   3.06168551e-02,
#          6.58785783e-02,   3.06057655e-03,   1.07496200e-01,
#          4.58179733e-03,   1.46842238e-01,   2.39103463e-02,
#          5.65251912e-02,   1.81605576e-02,   9.81541564e-03,
#          3.78555998e-02,   1.86270569e-02,   2.12730479e-01,
#          2.05940543e-02,   1.43969535e-01,   5.46000900e-02,
#          1.51474043e-02,   6.83478400e-02,   1.30638334e-01,
#          4.51155617e-02,   1.90400078e-02,   1.41398449e-01,
#          1.51626653e-01,   7.44024534e-04,   1.72475083e-02,
#          3.89678310e-03,   1.01825151e-01,   7.01159541e-04,
#          9.43416315e-02,   1.82325848e-02,   4.72987519e-02,
#          9.54269233e-02,   1.90686408e-01])

# %%
np.sum(np.square(y[50:] - (np.dot(x[50:], model.coef_) + model.intercept_)))
# Out:
# 3.0503160919839005

# %%
np.sum(np.square(y[p][50:] - (np.dot(x[p][50:], model.coef_) + model.intercept_)))/50
# Out:
# 0.078545133436026718

# %% [markdown]
# ### Is there a shorter way of calculating this error?
# Why yes, of course! Scikit-Learn to the rescue

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y[p][50:], np.dot(x[p][50:], model.coef_) + model.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-aba8edb23e80> in <module>
# ----> 1 mean_squared_error(y[p][50:], np.dot(x[p][50:], model.coef_) + model.intercept_)
#
# NameError: name 'p' is not defined

# %% [markdown]
# ### Why the slight discrepancy in values?
# Let's check the Documentation
# [http://scikit-learn.org/stable/modules/model_evaluation.html#mean-squared-error]
#
# Turns out sklearn sums N-1 values and not all N because Statistics
# [http://stats.stackexchange.com/questions/17890/what-is-the-difference-between-n-and-n-1-in-calculating-population-variance]

# %% [markdown]
# ## Is there an easier way to shuffle the data?
# I'm glad you asked [http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.5)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([ 0.8560574]), 0.05491858960427376)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
model.coef_, model.intercept_
# Out:
# (array([ 1.0369989]), -0.035769290071601068)

# %%
plt.scatter(x,y)
plt.plot(x, np.dot(x, model.coef_) + model.intercept_)

# %%
mean_squared_error(y_test, np.dot(x_test, model.coef_) + model.intercept_)
# Out:
# 0.071388325611252718

# %%
mean_squared_error(y_train, np.dot(x_train, model.coef_) + model.intercept_)
# Out:
# 0.076702444866570241

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, np.dot(x_test, model.coef_) + model.intercept_)

# %% [markdown]
# ## Ridge

# %%
mean_squared_error(y_test, np.dot(x_test, model.coef_) + model.intercept_)
# Out:
# 0.069445955321577324

# %%
mean_squared_error(y_train, np.dot(x_train, model.coef_) + model.intercept_)
# Out:
# 0.079800371048118851
